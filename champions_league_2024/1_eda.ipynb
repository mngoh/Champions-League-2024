# %% [markdown]
# # Champions League Data EDA
# ## Date: 05/20/2024
# ### Author: Martin Ngoh

# %%
# Load Packages
import pandas as pd
import numpy as np 
from helper import freq_plot, bar_plot, scatter_plot, box_plot, heat_map

# %%
# Load Data 
df =pd.read_csv('champions_league_team_data_raw.csv')

# %% [markdown]
# # Visualizations

# %%
# Goals by Season 
bar_plot(x='year', y='Gls', df = df)

# %%
# Ast by Season 
bar_plot(x='year', y='Ast', df = df)

# %% [markdown]
# # Distribution of Goals (Target)

# %%
# Plot Distribution of Goals 
freq_plot(df=df, x ='Gls')
# Out:
# /Users/Martin1/Desktop/GIT/champions_league_22/helper.py:11: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.displot(df, x=x, kde=True, palette='cool')

# %%
# Plot Distribution of Age
freq_plot(df=df, x ='Age')
# Out:
# /Users/Martin1/Desktop/GIT/champions_league_22/helper.py:11: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.displot(df, x=x, kde=True, palette='cool')

# %%
# Plot Distribution of Age
for x in df:
    freq_plot(df=df, x =x)
# Out:
# /Users/Martin1/Desktop/GIT/champions_league_22/helper.py:11: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.displot(df, x=x, kde=True, palette='cool')
# /Users/Martin1/Desktop/GIT/champions_league_22/helper.py:11: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.displot(df, x=x, kde=True, palette='cool')
# /Users/Martin1/Desktop/GIT/champions_league_22/helper.py:11: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.displot(df, x=x, kde=True, palette='cool')
# /Users/Martin1/Desktop/GIT/champions_league_22/helper.py:11: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.displot(df, x=x, kde=True, palette='cool')
# /Users/Martin1/Desktop/GIT/champions_league_22/helper.py:11: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.displot(df, x=x, kde=True, palette='cool')
# ...

# %% [markdown]
# ## Scatter Plots

# %%
# Scatter Plot 
for x in df:
    scatter_plot(x=x, y='Gls', df=df)
# Out:
# /Users/Martin1/Desktop/GIT/champions_league_22/helper.py:29: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.scatterplot(data=df, x=x, y=y, palette='cool')
# /Users/Martin1/Desktop/GIT/champions_league_22/helper.py:29: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.scatterplot(data=df, x=x, y=y, palette='cool')
# /Users/Martin1/Desktop/GIT/champions_league_22/helper.py:29: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.scatterplot(data=df, x=x, y=y, palette='cool')
# /Users/Martin1/Desktop/GIT/champions_league_22/helper.py:29: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.scatterplot(data=df, x=x, y=y, palette='cool')
# /Users/Martin1/Desktop/GIT/champions_league_22/helper.py:29: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.scatterplot(data=df, x=x, y=y, palette='cool')
# ...

# %% [markdown]
# # Heatmap

# %%
# Heat Map For Correlations 
corr = df.drop(['Squad', '# Pl', 'year'], axis = 1).corr()
heat_map(corr)
